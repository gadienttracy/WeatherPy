# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# We iterate through the coordinates, Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list. We add a decision statement with the logical operator not in to determine whether the found city is already in the cities list. If not, then we'll use the append() function to add it. 
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list. We create the for loop with the enumerate() method and reference the index and the city in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. In the conditional statement, we check if the remainder of the index divided by 50 is equal to 0 and if the index is greater than or equal to 50. If the statement is true, then the set_count and the record_count are incremented by 1.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city. Inside the conditional statement, we create the URL endpoint for each city, as before. However, we are removing the blank spaces in the city name and concatenating the city name with, city.replace(" ","+"). This will find the corresponding weather data for the city instead of finding the weather data for the first part of the city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city. Also, we add a print statement that tells us the record count and set count, and the city that is being processed.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. Then we add one to the record count before the next city is processed.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Create endpoint URL with each city.
city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | comodoro rivadavia
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | kantunilkin
# Processing Record 4 of Set 1 | humaita
# Processing Record 5 of Set 1 | namatanai
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | canutama
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | lazurne
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | tighina
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 1 | newport
# Processing Record 16 of Set 1 | sechura
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | caravelas
# Processing Record 19 of Set 1 | half moon bay
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | coquimbo
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | vardo
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | mehriz
# Processing Record 27 of Set 1 | guerrero negro
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | venado tuerto
# Processing Record 30 of Set 1 | arlit
# Processing Record 31 of Set 1 | kenai
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | chambas
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | pedernales
# Processing Record 37 of Set 1 | fairbanks
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | kununurra
# Processing Record 42 of Set 1 | were ilu
# Processing Record 43 of Set 1 | gazanjyk
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | sayansk
# Processing Record 46 of Set 1 | broome
# Processing Record 47 of Set 1 | mount isa
# Processing Record 48 of Set 1 | zacatepec
# Processing Record 49 of Set 1 | dalianwan
# Processing Record 50 of Set 1 | lesnikovo
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | wanning
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | bathsheba
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | ghansor
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | saint-pierre
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | salinopolis
# Processing Record 21 of Set 2 | banda aceh
# Processing Record 22 of Set 2 | muros
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | vestmanna
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | saint-louis
# Processing Record 30 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 2 | kapoeta
# Processing Record 32 of Set 2 | viedma
# Processing Record 33 of Set 2 | kanye
# Processing Record 34 of Set 2 | north bend
# Processing Record 35 of Set 2 | belyy yar
# Processing Record 36 of Set 2 | kutum
# Processing Record 37 of Set 2 | aksarka
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | gizo
# Processing Record 40 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | pucallpa
# Processing Record 43 of Set 2 | chabahar
# Processing Record 44 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | lorengau
# Processing Record 46 of Set 2 | barsovo
# Processing Record 47 of Set 2 | holme
# Processing Record 48 of Set 2 | goderich
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | saint-joseph
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | syracuse
# Processing Record 3 of Set 3 | ullapool
# Processing Record 4 of Set 3 | skibbereen
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | horasan
# Processing Record 7 of Set 3 | hualmay
# Processing Record 8 of Set 3 | bilma
# Processing Record 9 of Set 3 | eureka
# Processing Record 10 of Set 3 | eyemouth
# Processing Record 11 of Set 3 | sangar
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | farafenni
# Processing Record 14 of Set 3 | hasaki
# Processing Record 15 of Set 3 | starychi
# Processing Record 16 of Set 3 | picton
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | kenora
# Processing Record 19 of Set 3 | taltal
# Processing Record 20 of Set 3 | buchanan
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | ukiah
# Processing Record 23 of Set 3 | gombong
# Processing Record 24 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 3 | camden
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | manzhouli
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | rusii munti
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | batsfjord
# Processing Record 36 of Set 3 | constitucion
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | rikitea
# Processing Record 39 of Set 3 | gao
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | pryazha
# Processing Record 42 of Set 3 | santa lucia
# Processing Record 43 of Set 3 | havelock
# Processing Record 44 of Set 3 | orihuela
# Processing Record 45 of Set 3 | kefalos
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | isangel
# Processing Record 49 of Set 3 | kieta
# Processing Record 50 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 4 | murchison
# Processing Record 2 of Set 4 | san andres
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | soe
# Processing Record 5 of Set 4 | margate
# Processing Record 6 of Set 4 | dagana
# Processing Record 7 of Set 4 | presidencia roque saenz pena
# Processing Record 8 of Set 4 | broken hill
# Processing Record 9 of Set 4 | kandrian
# Processing Record 10 of Set 4 | poltava
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | roma
# Processing Record 15 of Set 4 | tuatapere
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | salalah
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | sur
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | nipawin
# Processing Record 23 of Set 4 | emet
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | kabare
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | great yarmouth
# Processing Record 29 of Set 4 | svetlyy
# Processing Record 30 of Set 4 | klooga
# Processing Record 31 of Set 4 | hofn
# Processing Record 32 of Set 4 | tsumeb
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | staryy nadym
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | haines junction
# Processing Record 37 of Set 4 | raga
# Processing Record 38 of Set 4 | deputatskiy
# Processing Record 39 of Set 4 | fort nelson
# Processing Record 40 of Set 4 | sept-iles
# Processing Record 41 of Set 4 | kasongo-lunda
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | xining
# Processing Record 44 of Set 4 | juneau
# Processing Record 45 of Set 4 | vaini
# Processing Record 46 of Set 4 | yellowknife
# Processing Record 47 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 4 | laguna de perlas
# Processing Record 49 of Set 4 | rawson
# Processing Record 50 of Set 4 | hovd
# Processing Record 1 of Set 5 | cimitarra
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | palermo
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | wagar
# Processing Record 7 of Set 5 | amalapuram
# Processing Record 8 of Set 5 | andros town
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | ust-ishim
# Processing Record 11 of Set 5 | eyl
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | berlevag
# Processing Record 15 of Set 5 | bodaybo
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | phuket
# Processing Record 18 of Set 5 | haian
# Processing Record 19 of Set 5 | sovetskoye
# Processing Record 20 of Set 5 | saint anthony
# Processing Record 21 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 5 | kaseda
# Processing Record 23 of Set 5 | laguna
# Processing Record 24 of Set 5 | nouadhibou
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | dzhebariki-khaya
# Processing Record 28 of Set 5 | bethel
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | strezhevoy
# Processing Record 31 of Set 5 | aubiere
# Processing Record 32 of Set 5 | antalaha
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | makakilo city
# Processing Record 36 of Set 5 | standerton
# Processing Record 37 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 5 | emba
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | ekhabi
# Processing Record 41 of Set 5 | ous
# Processing Record 42 of Set 5 | mandurah
# Processing Record 43 of Set 5 | ulundi
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | miraflores
# Processing Record 46 of Set 5 | angoram
# Processing Record 47 of Set 5 | ritchie
# Processing Record 48 of Set 5 | bogandinskiy
# Processing Record 49 of Set 5 | college
# Processing Record 50 of Set 5 | torbay
# Processing Record 1 of Set 6 | dunmore town
# Processing Record 2 of Set 6 | tasiilaq
# Processing Record 3 of Set 6 | mezhdurechensk
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | bambanglipuro
# Processing Record 6 of Set 6 | freetown
# Processing Record 7 of Set 6 | heihe
# Processing Record 8 of Set 6 | santa luzia
# Processing Record 9 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 6 | abasolo
# Processing Record 11 of Set 6 | birao
# Processing Record 12 of Set 6 | mount gambier
# Processing Record 13 of Set 6 | paidha
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | siteki
# Processing Record 16 of Set 6 | ayan
# Processing Record 17 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 6 | keffi
# Processing Record 19 of Set 6 | richards bay
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | kilindoni
# Processing Record 22 of Set 6 | codrington
# Processing Record 23 of Set 6 | abalak
# Processing Record 24 of Set 6 | khasan
# Processing Record 25 of Set 6 | el campo
# Processing Record 26 of Set 6 | port hardy
# Processing Record 27 of Set 6 | batagay-alyta
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | nantucket
# Processing Record 30 of Set 6 | sakakah
# Processing Record 31 of Set 6 | yaan
# Processing Record 32 of Set 6 | cerinza
# Processing Record 33 of Set 6 | anadyr
# Processing Record 34 of Set 6 | chicama
# Processing Record 35 of Set 6 | acari
# Processing Record 36 of Set 6 | sarakhs
# Processing Record 37 of Set 6 | ariquemes
# Processing Record 38 of Set 6 | georgiyevka
# Processing Record 39 of Set 6 | rudnogorsk
# Processing Record 40 of Set 6 | mayumba
# Processing Record 41 of Set 6 | lyubytino
# Processing Record 42 of Set 6 | south charleston
# Processing Record 43 of Set 6 | khvastovichi
# Processing Record 44 of Set 6 | camopi
# Processing Record 45 of Set 6 | lat yao
# Processing Record 46 of Set 6 | nisko
# Processing Record 47 of Set 6 | enumclaw
# Processing Record 48 of Set 6 | namie
# Processing Record 49 of Set 6 | zhigansk
# Processing Record 50 of Set 6 | hollins
# Processing Record 1 of Set 7 | mar del plata
# Processing Record 2 of Set 7 | srednekolymsk
# Processing Record 3 of Set 7 | moerai
# Processing Record 4 of Set 7 | saldanha
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | takestan
# Processing Record 7 of Set 7 | vrangel
# Processing Record 8 of Set 7 | kathmandu
# Processing Record 9 of Set 7 | vanavara
# Processing Record 10 of Set 7 | charapan
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | saint-augustin
# Processing Record 13 of Set 7 | qaqortoq
# Processing Record 14 of Set 7 | great falls
# Processing Record 15 of Set 7 | coahuayana
# Processing Record 16 of Set 7 | smithers
# Processing Record 17 of Set 7 | sirajganj
# Processing Record 18 of Set 7 | pevek
# Processing Record 19 of Set 7 | alta gracia
# Processing Record 20 of Set 7 | genhe
# Processing Record 21 of Set 7 | maskinonge
# Processing Record 22 of Set 7 | naze
# Processing Record 23 of Set 7 | tateyama
# Processing Record 24 of Set 7 | vao
# Processing Record 25 of Set 7 | walvis bay
# Processing Record 26 of Set 7 | yerbogachen
# Processing Record 27 of Set 7 | umm lajj
# Processing Record 28 of Set 7 | ixtapa
# Processing Record 29 of Set 7 | faya
# Processing Record 30 of Set 7 | nanortalik
# Processing Record 31 of Set 7 | whitecourt
# Processing Record 32 of Set 7 | praia
# Processing Record 33 of Set 7 | acarau
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | acapulco
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | porto novo
# Processing Record 38 of Set 7 | mansa
# Processing Record 39 of Set 7 | gotsu
# Processing Record 40 of Set 7 | hambantota
# Processing Record 41 of Set 7 | tiksi
# Processing Record 42 of Set 7 | okhtyrka
# Processing Record 43 of Set 7 | aklavik
# Processing Record 44 of Set 7 | castro
# Processing Record 45 of Set 7 | dera bugti
# Processing Record 46 of Set 7 | santiago del estero
# Processing Record 47 of Set 7 | kibondo
# Processing Record 48 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 7 | kamir
# Processing Record 50 of Set 7 | hokitika
# Processing Record 1 of Set 8 | yarmouth
# Processing Record 2 of Set 8 | is
# City not found. Skipping...
# Processing Record 3 of Set 8 | zenica
# Processing Record 4 of Set 8 | rumonge
# Processing Record 5 of Set 8 | kloulklubed
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | cabedelo
# Processing Record 8 of Set 8 | cairns
# Processing Record 9 of Set 8 | ola
# Processing Record 10 of Set 8 | santa cruz
# Processing Record 11 of Set 8 | libreville
# Processing Record 12 of Set 8 | paamiut
# Processing Record 13 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 8 | kyaka
# Processing Record 15 of Set 8 | villamontes
# Processing Record 16 of Set 8 | beringovskiy
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | pacific grove
# Processing Record 19 of Set 8 | bagotville
# Processing Record 20 of Set 8 | zaysan
# Processing Record 21 of Set 8 | koungou
# Processing Record 22 of Set 8 | la macarena
# Processing Record 23 of Set 8 | sarankhola
# Processing Record 24 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 8 | nikolskoye
# Processing Record 26 of Set 8 | muzhi
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | axim
# Processing Record 29 of Set 8 | egvekinot
# Processing Record 30 of Set 8 | fortuna
# Processing Record 31 of Set 8 | adeje
# Processing Record 32 of Set 8 | tieling
# Processing Record 33 of Set 8 | port lincoln
# Processing Record 34 of Set 8 | bluefields
# Processing Record 35 of Set 8 | spornoye
# Processing Record 36 of Set 8 | bondo
# Processing Record 37 of Set 8 | jizan
# Processing Record 38 of Set 8 | guisa
# Processing Record 39 of Set 8 | graaff-reinet
# Processing Record 40 of Set 8 | nishihara
# Processing Record 41 of Set 8 | riohacha
# Processing Record 42 of Set 8 | iqaluit
# Processing Record 43 of Set 8 | uporovo
# Processing Record 44 of Set 8 | brenham
# Processing Record 45 of Set 8 | pathein
# Processing Record 46 of Set 8 | kirakira
# Processing Record 47 of Set 8 | kungurtug
# Processing Record 48 of Set 8 | sayville
# Processing Record 49 of Set 8 | laviana
# Processing Record 50 of Set 8 | karratha
# Processing Record 1 of Set 9 | narsaq
# Processing Record 2 of Set 9 | sorrento
# Processing Record 3 of Set 9 | atasu
# Processing Record 4 of Set 9 | winslow
# Processing Record 5 of Set 9 | palana
# Processing Record 6 of Set 9 | tessalit
# Processing Record 7 of Set 9 | metehara
# City not found. Skipping...
# Processing Record 8 of Set 9 | cherskiy
# Processing Record 9 of Set 9 | vila velha
# Processing Record 10 of Set 9 | tiznit
# Processing Record 11 of Set 9 | rosarito
# Processing Record 12 of Set 9 | usagara
# Processing Record 13 of Set 9 | bealanana
# Processing Record 14 of Set 9 | knysna
# Processing Record 15 of Set 9 | burlatskoye
# Processing Record 16 of Set 9 | nueve de julio
# Processing Record 17 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 9 | kindu
# Processing Record 19 of Set 9 | ravar
# Processing Record 20 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 9 | galle
# Processing Record 22 of Set 9 | havoysund
# Processing Record 23 of Set 9 | vagur
# Processing Record 24 of Set 9 | tazmalt
# Processing Record 25 of Set 9 | usinsk
# Processing Record 26 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 9 | longyearbyen
# Processing Record 28 of Set 9 | benguela
# Processing Record 29 of Set 9 | novoagansk
# Processing Record 30 of Set 9 | pochutla
# Processing Record 31 of Set 9 | zarand
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | marzuq
# Processing Record 34 of Set 9 | lethem
# Processing Record 35 of Set 9 | kabanjahe
# Processing Record 36 of Set 9 | preobrazheniye
# Processing Record 37 of Set 9 | kamina
# Processing Record 38 of Set 9 | labuhan
# Processing Record 39 of Set 9 | lima duarte
# Processing Record 40 of Set 9 | douentza
# Processing Record 41 of Set 9 | inta
# Processing Record 42 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 43 of Set 9 | teya
# Processing Record 44 of Set 9 | brae
# Processing Record 45 of Set 9 | paita
# Processing Record 46 of Set 9 | esperance
# Processing Record 47 of Set 9 | mabaruma
# Processing Record 48 of Set 9 | port arthur
# Processing Record 49 of Set 9 | nelson bay
# Processing Record 50 of Set 9 | baoqing
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | aginskoye
# Processing Record 3 of Set 10 | velsk
# Processing Record 4 of Set 10 | meulaboh
# Processing Record 5 of Set 10 | baghdad
# Processing Record 6 of Set 10 | korla
# Processing Record 7 of Set 10 | wakkanai
# Processing Record 8 of Set 10 | udachnyy
# Processing Record 9 of Set 10 | kalemie
# Processing Record 10 of Set 10 | ulagan
# Processing Record 11 of Set 10 | kariapatti
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | elizabeth city
# Processing Record 14 of Set 10 | nizhniy bestyakh
# Processing Record 15 of Set 10 | marsh harbour
# Processing Record 16 of Set 10 | ladario
# Processing Record 17 of Set 10 | kaniama
# Processing Record 18 of Set 10 | sioux lookout
# Processing Record 19 of Set 10 | suraabad
# Processing Record 20 of Set 10 | roald
# Processing Record 21 of Set 10 | lagos
# Processing Record 22 of Set 10 | hecun
# Processing Record 23 of Set 10 | ouegoa
# Processing Record 24 of Set 10 | arzgir
# Processing Record 25 of Set 10 | coihaique
# Processing Record 26 of Set 10 | mareeba
# Processing Record 27 of Set 10 | eenhana
# Processing Record 28 of Set 10 | atbasar
# Processing Record 29 of Set 10 | himora
# City not found. Skipping...
# Processing Record 30 of Set 10 | san patricio
# Processing Record 31 of Set 10 | tiangua
# Processing Record 32 of Set 10 | porrentruy
# Processing Record 33 of Set 10 | ceres
# Processing Record 34 of Set 10 | bowen
# Processing Record 35 of Set 10 | ust-kuyga
# Processing Record 36 of Set 10 | caluquembe
# Processing Record 37 of Set 10 | te anau
# Processing Record 38 of Set 10 | san isidro
# Processing Record 39 of Set 10 | marawi
# Processing Record 40 of Set 10 | union
# Processing Record 41 of Set 10 | mangan
# Processing Record 42 of Set 10 | troitskoye
# Processing Record 43 of Set 10 | pamplona
# Processing Record 44 of Set 10 | batagay
# Processing Record 45 of Set 10 | ternate
# Processing Record 46 of Set 10 | kisangani
# Processing Record 47 of Set 10 | vestmannaeyjar
# Processing Record 48 of Set 10 | meiktila
# Processing Record 49 of Set 10 | male
# Processing Record 50 of Set 10 | howard springs
# Processing Record 1 of Set 11 | talakan
# Processing Record 2 of Set 11 | kangaba
# Processing Record 3 of Set 11 | osmena
# Processing Record 4 of Set 11 | coos bay
# Processing Record 5 of Set 11 | mitsamiouli
# Processing Record 6 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 11 | anchorage
# Processing Record 8 of Set 11 | baoning
# Processing Record 9 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 10 of Set 11 | omboue
# Processing Record 11 of Set 11 | jieshi
# Processing Record 12 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 11 | bud
# Processing Record 14 of Set 11 | rampura
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | troy
# Processing Record 17 of Set 11 | chegdomyn
# Processing Record 18 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 19 of Set 11 | canon city
# Processing Record 20 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 11 | ottawa
# Processing Record 22 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 11 | dhidhdhoo
# Processing Record 24 of Set 11 | atambua
# Processing Record 25 of Set 11 | nizwa
# Processing Record 26 of Set 11 | zhezkazgan
# Processing Record 27 of Set 11 | penzance
# Processing Record 28 of Set 11 | barcelos
# Processing Record 29 of Set 11 | matara
# Processing Record 30 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 11 | lasa
# Processing Record 32 of Set 11 | buncrana
# Processing Record 33 of Set 11 | fort-shevchenko
# Processing Record 34 of Set 11 | zaranj
# Processing Record 35 of Set 11 | manzanillo
# Processing Record 36 of Set 11 | sorland
# Processing Record 37 of Set 11 | chapais
# Processing Record 38 of Set 11 | oga
# Processing Record 39 of Set 11 | fare
# Processing Record 40 of Set 11 | kasangulu
# Processing Record 41 of Set 11 | cangucu
# Processing Record 42 of Set 11 | nawa
# Processing Record 43 of Set 11 | ust-nera
# Processing Record 44 of Set 11 | port macquarie
# Processing Record 45 of Set 11 | west plains
# Processing Record 46 of Set 11 | todos santos
# Processing Record 47 of Set 11 | kanpur
# Processing Record 48 of Set 11 | sisimiut
# Processing Record 49 of Set 11 | souillac
# Processing Record 50 of Set 11 | shakawe
# Processing Record 1 of Set 12 | aswan
# Processing Record 2 of Set 12 | yuanping
# Processing Record 3 of Set 12 | cascais
# Processing Record 4 of Set 12 | severnoye
# Processing Record 5 of Set 12 | nioro
# Processing Record 6 of Set 12 | beyneu
# Processing Record 7 of Set 12 | wattegama
# Processing Record 8 of Set 12 | finschhafen
# Processing Record 9 of Set 12 | apricena
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | husavik
# Processing Record 12 of Set 12 | yar-sale
# Processing Record 13 of Set 12 | greytown
# Processing Record 14 of Set 12 | sasebo
# Processing Record 15 of Set 12 | quesnel
# Processing Record 16 of Set 12 | nalut
# Processing Record 17 of Set 12 | muravlenko
# Processing Record 18 of Set 12 | mandalgovi
# Processing Record 19 of Set 12 | moree
# Processing Record 20 of Set 12 | puerto carreno
# Processing Record 21 of Set 12 | shaoxing
# Processing Record 22 of Set 12 | mataram
# Processing Record 23 of Set 12 | asau
# Processing Record 24 of Set 12 | avera
# Processing Record 25 of Set 12 | kysyl-syr
# Processing Record 26 of Set 12 | talara
# Processing Record 27 of Set 12 | kahului
# Processing Record 28 of Set 12 | ebebiyin
# Processing Record 29 of Set 12 | sola
# Processing Record 30 of Set 12 | imbituba
# Processing Record 31 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 12 | arman
# Processing Record 33 of Set 12 | muli
# Processing Record 34 of Set 12 | atikokan
# Processing Record 35 of Set 12 | kansanshi
# Processing Record 36 of Set 12 | pascagoula
# Processing Record 37 of Set 12 | uong bi
# Processing Record 38 of Set 12 | maruko
# Processing Record 39 of Set 12 | solnechnyy
# Processing Record 40 of Set 12 | los llanos de aridane
# Processing Record 41 of Set 12 | grand gaube
# Processing Record 42 of Set 12 | sakassou
# Processing Record 43 of Set 12 | moron
# Processing Record 44 of Set 12 | copiapo
# Processing Record 45 of Set 12 | hohhot
# Processing Record 46 of Set 12 | pangnirtung
# Processing Record 47 of Set 12 | dongsheng
# Processing Record 48 of Set 12 | misratah
# Processing Record 49 of Set 12 | karasjok
# Processing Record 50 of Set 12 | huarmey
# Processing Record 1 of Set 13 | nybro
# Processing Record 2 of Set 13 | khandyga
# Processing Record 3 of Set 13 | ketchikan
# Processing Record 4 of Set 13 | vera cruz
# Processing Record 5 of Set 13 | baruun-urt
# Processing Record 6 of Set 13 | general pico
# Processing Record 7 of Set 13 | kedrovyy
# Processing Record 8 of Set 13 | sistranda
# Processing Record 9 of Set 13 | general roca
# Processing Record 10 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 13 | vagamo
# Processing Record 12 of Set 13 | ngunguru
# Processing Record 13 of Set 13 | wajir
# Processing Record 14 of Set 13 | puerto escondido
# Processing Record 15 of Set 13 | san ramon
# Processing Record 16 of Set 13 | xinzhi
# Processing Record 17 of Set 13 | katima mulilo
# Processing Record 18 of Set 13 | moranbah
# Processing Record 19 of Set 13 | nosy varika
# Processing Record 20 of Set 13 | toktogul
# Processing Record 21 of Set 13 | syamzha
# Processing Record 22 of Set 13 | sol-iletsk
# Processing Record 23 of Set 13 | concepcion del oro
# Processing Record 24 of Set 13 | aleksandrov gay
# Processing Record 25 of Set 13 | jalu
# Processing Record 26 of Set 13 | boddam
# Processing Record 27 of Set 13 | los andes
# Processing Record 28 of Set 13 | borovskoy
# Processing Record 29 of Set 13 | bowling green
# Processing Record 30 of Set 13 | gigmoto
# Processing Record 31 of Set 13 | antsohihy
# Processing Record 32 of Set 13 | pavlodar
# Processing Record 33 of Set 13 | valparaiso
# Processing Record 34 of Set 13 | ergani
# Processing Record 35 of Set 13 | maniitsoq
# Processing Record 36 of Set 13 | camamu
# Processing Record 37 of Set 13 | oistins
# Processing Record 38 of Set 13 | barbastro
# Processing Record 39 of Set 13 | adrar
# Processing Record 40 of Set 13 | polovinnoye
# Processing Record 41 of Set 13 | nabire
# Processing Record 42 of Set 13 | george town
# Processing Record 43 of Set 13 | joshimath
# Processing Record 44 of Set 13 | bousso
# Processing Record 45 of Set 13 | kuusamo
# Processing Record 46 of Set 13 | at-bashi
# Processing Record 47 of Set 13 | kawardha
# Processing Record 48 of Set 13 | havre-saint-pierre
# Processing Record 49 of Set 13 | belaya gora
# Processing Record 50 of Set 13 | tual
# Processing Record 1 of Set 14 | chumikan
# Processing Record 2 of Set 14 | west bay
# Processing Record 3 of Set 14 | meadow lake
# Processing Record 4 of Set 14 | wahiawa
# Processing Record 5 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 14 | enterprise
# Processing Record 7 of Set 14 | doka
# Processing Record 8 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 9 of Set 14 | ko samui
# Processing Record 10 of Set 14 | carutapera
# Processing Record 11 of Set 14 | cahors
# Processing Record 12 of Set 14 | maua
# Processing Record 13 of Set 14 | esil
# Processing Record 14 of Set 14 | kiruna
# Processing Record 15 of Set 14 | buckeye
# Processing Record 16 of Set 14 | tsalka
# Processing Record 17 of Set 14 | alta floresta
# Processing Record 18 of Set 14 | zheleznodorozhnyy
# Processing Record 19 of Set 14 | springdale
# Processing Record 20 of Set 14 | taywarah
# Processing Record 21 of Set 14 | khurba
# Processing Record 22 of Set 14 | come
# Processing Record 23 of Set 14 | gat
# Processing Record 24 of Set 14 | jiangkou
# Processing Record 25 of Set 14 | amuntai
# Processing Record 26 of Set 14 | sambava
# Processing Record 27 of Set 14 | chapleau
# Processing Record 28 of Set 14 | dehloran
# Processing Record 29 of Set 14 | barinas
# Processing Record 30 of Set 14 | honiara
# Processing Record 31 of Set 14 | salawagan
# Processing Record 32 of Set 14 | inuvik
# Processing Record 33 of Set 14 | tacoronte
# Processing Record 34 of Set 14 | sao desiderio
# Processing Record 35 of Set 14 | olafsvik
# Processing Record 36 of Set 14 | dakar
# Processing Record 37 of Set 14 | ambon
# Processing Record 38 of Set 14 | tynda
# Processing Record 39 of Set 14 | melo
# Processing Record 40 of Set 14 | alnashi
# Processing Record 41 of Set 14 | vila franca do campo
# Processing Record 42 of Set 14 | kudahuvadhoo
# Processing Record 43 of Set 14 | manaure
# Processing Record 44 of Set 14 | tinskoy
# Processing Record 45 of Set 14 | victor harbor
# Processing Record 46 of Set 14 | iisalmi
# Processing Record 47 of Set 14 | uige
# Processing Record 48 of Set 14 | evensk
# Processing Record 49 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 14 | fushe-arrez
# Processing Record 1 of Set 15 | vaitape
# Processing Record 2 of Set 15 | chara
# Processing Record 3 of Set 15 | chor
# Processing Record 4 of Set 15 | hwange
# Processing Record 5 of Set 15 | port moresby
# Processing Record 6 of Set 15 | flin flon
# Processing Record 7 of Set 15 | nanakuli
# Processing Record 8 of Set 15 | bontang
# Processing Record 9 of Set 15 | laureles
# Processing Record 10 of Set 15 | xuddur
# Processing Record 11 of Set 15 | jiexiu
# Processing Record 12 of Set 15 | mango
# Processing Record 13 of Set 15 | noumea
# Processing Record 14 of Set 15 | pontes e lacerda
# Processing Record 15 of Set 15 | albanel
# Processing Record 16 of Set 15 | wawa
# Processing Record 17 of Set 15 | olinda
# Processing Record 18 of Set 15 | kiama
# Processing Record 19 of Set 15 | urucara
# Processing Record 20 of Set 15 | lufilufi
# Processing Record 21 of Set 15 | maragogi
# Processing Record 22 of Set 15 | sabang
# Processing Record 23 of Set 15 | churapcha
# Processing Record 24 of Set 15 | gazojak
# Processing Record 25 of Set 15 | krasnyy yar
# Processing Record 26 of Set 15 | spring hill
# Processing Record 27 of Set 15 | saint-jerome
# Processing Record 28 of Set 15 | caraz
# Processing Record 29 of Set 15 | pedasi
# Processing Record 30 of Set 15 | pafos
# Processing Record 31 of Set 15 | hami
# Processing Record 32 of Set 15 | bilibino
# Processing Record 33 of Set 15 | port-gentil
# Processing Record 34 of Set 15 | fayaoue
# Processing Record 35 of Set 15 | rabo de peixe
# Processing Record 36 of Set 15 | mortka
# Processing Record 37 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 15 | ewa beach
# Processing Record 39 of Set 15 | olenino
# Processing Record 40 of Set 15 | voh
# Processing Record 41 of Set 15 | santa flavia
# Processing Record 42 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 43 of Set 15 | ulladulla
# Processing Record 44 of Set 15 | palmer
# Processing Record 45 of Set 15 | talnakh
# Processing Record 46 of Set 15 | matamoros
# Processing Record 47 of Set 15 | khairpur nathan shah
# Processing Record 48 of Set 15 | rossland
# Processing Record 49 of Set 15 | scarborough
# Processing Record 50 of Set 15 | mahibadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Comodoro Rivadavia      AR -45.8667  -67.5000     73.26        35
# 1          Butaritari      KI   3.0707  172.7902     81.61        78
# 2         Kantunilkin      MX  21.0917  -87.4500     78.64        99
# 3             Humaita      BR  -7.5061  -63.0208     73.71        99
# 4           Namatanai      PG  -3.6667  152.4333     79.27        83
# 5               Kapaa      US  22.0752 -159.3190     78.78        70
# 6            Canutama      BR  -6.5339  -64.3831     73.33        99
# 7     Arraial Do Cabo      BR -22.9661  -42.0278     75.33        88
# 8               Airai      TL  -8.9266  125.4092     71.78        65
# 9             Lazurne      UA  46.0840   32.5295     33.03        91
#
#    Cloudiness  Wind Speed Current Description
# 0           0       12.66           clear sky
# 1         100       15.64          light rain
# 2           6        3.42           clear sky
# 3         100        1.97     overcast clouds
# 4         100        8.86          light rain
# 5          75        1.01       broken clouds
# 6         100        1.28       moderate rain
# 7         100        4.99     overcast clouds
# 8         100        5.30     overcast clouds
# 9         100        8.05     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
